# %%
import tensorflow_data_validation as tfdv
from tensorflow_data_validation.utils import stats_util
import pyarrow as pa
from metaflow import Flow

# %%
run = Flow('ValidationFlow').latest_successful_run

# %%
run.data
# Out:
# <MetaflowData: anomalies, ARTIFACT_PATH, save_dir, valid_stats, validate_query, name, PROJECT_ID, schema, train_stats, training_query, valid_data, train_data>

# %%
tfdv.visualize_statistics(lhs_statistics=run.data.train_stats, rhs_statistics=run.data.valid_stats, 
                          lhs_name='train', rhs_name='valid')
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
tfdv.display_schema(run.data.schema)

# %%
tfdv.display_anomalies(run.data.anomalies)

# %%
# Out:
#                             Type  Presence Valency          Domain
# Feature name
# 'pickup_community_area'      INT  required                       -
# 'fare'                     FLOAT  required                       -
# 'trip_start_month'           INT  required                       -
# 'trip_start_hour'            INT  required                       -
# 'trip_start_day'             INT  required                       -
# 'trip_start_timestamp'     BYTES  required                       -
# 'pickup_latitude'          FLOAT  required                       -
# 'pickup_longitude'         FLOAT  required                       -
# 'dropoff_latitude'         FLOAT  required                       -
# 'dropoff_longitude'        FLOAT  required                       -
# 'trip_miles'               FLOAT  required                       -
# 'pickup_census_tract'        INT  required                       -
# 'dropoff_census_tract'       INT  required                       -
# ...

# %%
tfdv.display_anomalies(run.data.anomalies)
# Out:
# <h4 style="color:green;">No anomalies found.</h4>
